# %%
import random as r

# %%
import random as r

def dice1():
    return r.randint(1,6)

win_value=100
def start():
    player1=0
    player2=0
    
    while True:
        x1=dice1()
        player_1=input("Enter 1 for player1  : ")
        if player_1=="1" and player1<94:
            player1+=x1
            print(" player1 you got : {} you are at {} \n".format(x1,player1))
            if player1==1:
                player1+=37
                print("player1 you got ladder you wil go from 1 to 38\n")
            elif player1==4:
                player1+=10
                print("player1 you got ladder you will go from 4 to 14\n")
            elif player1==9:
                player1+=22
                print("player1 you got ladder you will go from 9 to 31\n")
            elif player1==28:
                player1+=56
                print("player1 you got ladder you will go from 28 to 84\n")
            elif player1==21:
                player1+=21
                print("player1 you got ladder you will go from 21 to 42\n")
            elif player1==51:
                player1+=16
                print("player1 you got ladder you will go from 51 to 67\n")
            elif player1==72:
                player1+=19
                print("player1 you got ladder you will go from 72 to 91\n")
            elif player1==80:
                player1+=19
                print("player1 you got ladder you will go from 80 to 99\n")
            elif player1==17:
                player1-=11
                print("player1 you got snake you will go from 17 to 7\n")
            elif player1==54:
                player1-=20
                print("player1 you got snake you will go from 54 to 34\n")
            elif player1==63:
                player1-=45
                print("player1 you got snake you will go from 63 to 18\n")
            elif player1==64:
                player1-=4
                print("player1 you got snake you will go from 64 to 60\n")
            elif player1==87:
                player1-=51
                print("player1 you got snake you will go from 87 to 36\n")
            elif player1==92:
                player1-=19
                print("player1 you got snake you will go from 92 to 73\n")
            elif player1==95:
                player1-=20
                print("player1 you got snake you will go from 95 to 75\n")
            elif player1==98:
                player1-=19
                print("player1 you got snake you will go from 98 to 79\n")
        elif player1==94:
            if x1 in range(1,7): 
                player1+=x1
        elif player1==95:
            if x1 in range(1,6):
                player1+=x1
        elif player1==96:
            if x1 in range(1,5):
                player1+=x1
        elif player1==97:
            if x1 in range(1,4):
                player1+=x1
        elif player1==98:
            if x1 in range(1,3):
                player1+=x1
        elif player1==99:
            if x1==1:
                player1+=1 
        elif player1==100:
            print("player1 win")
            break
            
            
        x2=dice1()        
        player_2=input("Enter 2 for player2 :")       
        if player_2=="2" and player2<94:
            player2+=x2
            print(" player2 you got : {} you are at {} \n".format(x2,player2))
            if player2==1:
                player2+=37
                print(" player2 you got ladder you wil go from 1 to 38\n")
            elif player2==4:
                player2+=10
                print("player2 you got ladder you will go from 4 to 14\n")
            elif player2==9:
                player2+=22
                print("player2 you got ladder you will go from 9 to 31\n")
            elif player2==28:
                player2+=56
                print(" player2 you got ladder you will go from 28 to 84\n")
            elif player2==21:
                player2+=21
                print(" player2 you got ladder you will go from 21 to 42\n")
            elif player2==51:
                player2+=16
                print("player2 you got ladder you will go from 51 to 67\n")
            elif player2==72:
                player2+=19
                print("player2 you got ladder you will go from 72 to 91\n")
            elif player2==80:
                player2+=19
                print("player2 you got ladder you will go from 80 to 99\n")
            elif player2==17:
                player2-=11
                print("player2 you got snake you will go from 17 to 7\n")
            elif player2==54:
                player2-=20
                print(" player2 you got snake you will go from 54 to 34\n")
            elif player2==63:
                player2-=45
                print(" player2 you got snake you will go from 63 to 18\n")
            elif player2==64:
                player2-=4
                print(" player2 you got snake you will go from 64 to 60\n")
            elif player2==87:
                player2-=51
                print("player2 you got snake you will go from 87 to 36\n")
            elif player2==92:
                player2-=19
                print("player2 you got snake you will go from 92 to 73\n")
            elif player2==95:
                player2-=20
                print("player2 you got snake you will go from 95 to 75\n")
            elif player2==98:
                player2-=19
                print("player2 you got snake you will go from 98 to 79\n")
        elif player2==94:
            if x2 in range(1,7): 
                player2+=x2
        elif player2==95:
            if x2 in range(1,6):
                player2+=x2
        elif player2==96:
            if x2 in range(1,5):
                player2+=x2
        elif player2==97:
            if x2 in range(1,4):
                player2+=x2
        elif player2==98:
            if x2 in range(1,3):
                player2+=x2
        elif player2==99:
            if x2==1:
                player2+=1 
        elif player2==100:
            print("player2 win")
            break
                
            

    
start()
# Out:
# Enter 1 for player1  : 1
#  player1 you got : 1 you are at 1
#
# player1 you got ladder you wil go from 1 to 38
#
# Enter 2 for player2 :2
#  player2 you got : 2 you are at 2
#
# Enter 1 for player1  : 1
#  player1 you got : 5 you are at 43
#
# Enter 2 for player2 :2
#  player2 you got : 1 you are at 3
#
# Enter 1 for player1  : 1
#  player1 you got : 2 you are at 45
#
# Enter 2 for player2 :2
#  player2 you got : 5 you are at 8
#
# Enter 1 for player1  : 1
#  player1 you got : 5 you are at 50
#
# Enter 2 for player2 :2
#  player2 you got : 5 you are at 13
#
# Enter 1 for player1  : 1
#  player1 you got : 1 you are at 51
#
# player1 you got ladder you will go from 51 to 67
#
# Enter 2 for player2 :2
#  player2 you got : 5 you are at 18
#
# Enter 1 for player1  : 1
#  player1 you got : 3 you are at 70
#
# Enter 2 for player2 :2
#  player2 you got : 2 you are at 20
#
# Enter 1 for player1  : 1
#  player1 you got : 1 you are at 71
#
# Enter 2 for player2 :2
# ...

# %% [markdown]
# ## <img src="ludo.png">
